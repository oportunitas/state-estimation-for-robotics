# %%
"""
compute the mean and variance (the first 2 moments) of the posterior pdf from the 2.1.2 quiz
"""

# %run -i ../2.marginalization-bayes-rule-inference/explore.ipynb

# %%
if __name__ == '__main__' and '__file__' not in globals():
  location = _make_gaussian(0.0, 1.0)
  sensor_reading = 2.0
  location_after_sensor = _make_posterior(sensor_reading)
